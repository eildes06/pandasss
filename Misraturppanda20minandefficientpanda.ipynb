# %% [markdown]
# <a href="https://colab.research.google.com/github/eildes06/pandasss/blob/main/Misraturppanda20minandefficientpanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
titanic= pd.read_csv("/content/drive/MyDrive/titanic.csv")


titanic
#df.to_csv('')
#the thing down is dataframe
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
#dataframe is combination of series object

# %%
titanic["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic["fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
titanic[["age","embark_town"]]
# Out:
#       age  embark_town
# 0    22.0  Southampton
# 1    38.0    Cherbourg
# 2    26.0  Southampton
# 3    35.0  Southampton
# 4    35.0  Southampton
# ..    ...          ...
# 886  27.0  Southampton
# 887  19.0  Southampton
# 888   NaN  Southampton
# 889  26.0    Cherbourg
# 890  32.0   Queenstown
#
# [891 rows x 2 columns]

# %%
#geting row
titanic.loc[4]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                     35
# sibsp                    0
# parch                    0
# fare                  8.05
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 4, dtype: object

# %%
#filtering= 2 things ara important what ara call the shells and condition
titanic[titanic["age"]>30]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# 6           0       1    male  54.0  ...     E  Southampton     no   True
# 11          1       1  female  58.0  ...     C  Southampton    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 873         0       3    male  47.0  ...   NaN  Southampton     no   True
# 879         1       1  female  56.0  ...     C    Cherbourg    yes  False
# 881         0       3    male  33.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [305 rows x 15 columns]

# %%
titanic.loc[titanic["age"]>30]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# 6           0       1    male  54.0  ...     E  Southampton     no   True
# 11          1       1  female  58.0  ...     C  Southampton    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 873         0       3    male  47.0  ...   NaN  Southampton     no   True
# 879         1       1  female  56.0  ...     C    Cherbourg    yes  False
# 881         0       3    male  33.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [305 rows x 15 columns]

# %%
titanic["age"]>30
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
#in hhere parantesiz you have to put for each condition
#if you you are combining 2 and more condition prantezis so important

titanic[(titanic["age"]>30)&(titanic["fare"]<50)]#this is and object
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# 11          1       1  female  58.0  ...     C  Southampton    yes   True
# 13          0       3    male  39.0  ...   NaN  Southampton     no  False
# 15          1       2  female  55.0  ...   NaN  Southampton    yes   True
# 18          0       3  female  31.0  ...   NaN  Southampton     no  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 872         0       1    male  33.0  ...     B  Southampton     no   True
# 873         0       3    male  47.0  ...   NaN  Southampton     no   True
# 881         0       3    male  33.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [222 rows x 15 columns]

# %%
titanic[(titanic["age"]>30)|(titanic["fare"]<50)]#this one is or
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [813 rows x 15 columns]

# %%
titanic[titanic["pclass"].isin(["1","3"])]
#here is people who stay pc 1 or 3
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [707 rows x 15 columns]

# %%
#here there is tilda~ means people who dont stay 1or 3 means people who stay 2:)
##boolean bir ifade oluşturduktan sonra ttilde ile değilini alabiliyrosunuz.
#eğer boolean dönen sonuçlar == operatörü ile olşturuldu ise ilgili kısmı parantez içine almanız lazım
#parantez içine aldıktan sonra başına tilde bırakırsanız python anlıyor yoksa tilde nereyi tam olarak kapsıyor anlamıyor

#df[~(df.column == 3)]
#fakat df[~df.column.isin('abc')]
#burada ise paranteze gerek yok sanırım.


titanic[~titanic["pclass"].isin(["1","3"])]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 9           1       2  female  14.0  ...   NaN    Cherbourg    yes  False
# 15          1       2  female  55.0  ...   NaN  Southampton    yes   True
# 17          1       2    male   NaN  ...   NaN  Southampton    yes   True
# 20          0       2    male  35.0  ...   NaN  Southampton     no   True
# 21          1       2    male  34.0  ...     D  Southampton    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 866         1       2  female  27.0  ...   NaN    Cherbourg    yes  False
# 874         1       2  female  28.0  ...   NaN    Cherbourg    yes  False
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 883         0       2    male  28.0  ...   NaN  Southampton     no   True
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
#
# [184 rows x 15 columns]

# %%
#find people who are age 30
titanic[titanic["age"]==30]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 79          1       3  female  30.0  ...   NaN  Southampton    yes   True
# 157         0       3    male  30.0  ...   NaN  Southampton     no   True
# 178         0       2    male  30.0  ...   NaN  Southampton     no   True
# 213         0       2    male  30.0  ...   NaN  Southampton     no   True
# 219         0       2    male  30.0  ...   NaN  Southampton     no   True
# 244         0       3    male  30.0  ...   NaN    Cherbourg     no   True
# 253         0       3    male  30.0  ...   NaN  Southampton     no  False
# 257         1       1  female  30.0  ...     B  Southampton    yes   True
# 286         1       3    male  30.0  ...   NaN  Southampton    yes   True
# 308         0       2    male  30.0  ...   NaN    Cherbourg     no  False
# 309         1       1  female  30.0  ...     E    Cherbourg    yes   True
# 322         1       2  female  30.0  ...   NaN   Queenstown    yes   True
# ...

# %%
titanic[~(titanic['age']==30)]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [866 rows x 15 columns]

# %%
titanic[titanic["age"]!=30]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [866 rows x 15 columns]

# %%
titanic[titanic["age"]==30]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 79          1       3  female  30.0  ...   NaN  Southampton    yes   True
# 157         0       3    male  30.0  ...   NaN  Southampton     no   True
# 178         0       2    male  30.0  ...   NaN  Southampton     no   True
# 213         0       2    male  30.0  ...   NaN  Southampton     no   True
# 219         0       2    male  30.0  ...   NaN  Southampton     no   True
# 244         0       3    male  30.0  ...   NaN    Cherbourg     no   True
# 253         0       3    male  30.0  ...   NaN  Southampton     no  False
# 257         1       1  female  30.0  ...     B  Southampton    yes   True
# 286         1       3    male  30.0  ...   NaN  Southampton    yes   True
# 308         0       2    male  30.0  ...   NaN    Cherbourg     no  False
# 309         1       1  female  30.0  ...     E    Cherbourg    yes   True
# 322         1       2  female  30.0  ...   NaN   Queenstown    yes   True
# ...

# %% [markdown]
# Changing dataframe

# %%
#adding new cloumn
titanic["Total Fare"]=(titanic["sibsp"]+titanic[""]+1)*titanic["fare"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-556ff292a2e8> in <module>()
#       1 #adding new cloumn
# ...

# %%
#to change all columns name,
# titanic.columns=[]

# %%
#change column name but only one or more not all
titanic.rename(columns={"fare":"Ticket fee","survived":":)"})
# Out:
#      :)  pclass     sex   age  sibsp  ...  adult_male  deck  embark_town alive  alone
# 0     0       3    male  22.0      1  ...        True   NaN  Southampton    no  False
# 1     1       1  female  38.0      1  ...       False     C    Cherbourg   yes  False
# 2     1       3  female  26.0      0  ...       False   NaN  Southampton   yes   True
# 3     1       1  female  35.0      1  ...       False     C  Southampton   yes  False
# 4     0       3    male  35.0      0  ...        True   NaN  Southampton    no   True
# ..   ..     ...     ...   ...    ...  ...         ...   ...          ...   ...    ...
# 886   0       2    male  27.0      0  ...        True   NaN  Southampton    no   True
# 887   1       1  female  19.0      0  ...       False     B  Southampton   yes   True
# 888   0       3  female   NaN      1  ...       False   NaN  Southampton    no  False
# 889   1       1    male  26.0      0  ...        True     C    Cherbourg   yes   True
# ...

# %%
#reset index
filtered_titanic=titanic[titanic["age"]==30]
filtered_titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 79          1       3  female  30.0  ...   NaN  Southampton    yes   True
# 157         0       3    male  30.0  ...   NaN  Southampton     no   True
# 178         0       2    male  30.0  ...   NaN  Southampton     no   True
# 213         0       2    male  30.0  ...   NaN  Southampton     no   True
# 219         0       2    male  30.0  ...   NaN  Southampton     no   True
# 244         0       3    male  30.0  ...   NaN    Cherbourg     no   True
# 253         0       3    male  30.0  ...   NaN  Southampton     no  False
# 257         1       1  female  30.0  ...     B  Southampton    yes   True
# 286         1       3    male  30.0  ...   NaN  Southampton    yes   True
# 308         0       2    male  30.0  ...   NaN    Cherbourg     no  False
# 309         1       1  female  30.0  ...     E    Cherbourg    yes   True
# 322         1       2  female  30.0  ...   NaN   Queenstown    yes   True
# ...

# %%
filtered_titanic=titanic[titanic["age"]==30].reset_index()
filtered_titanic
#it add one more column and it put a name is index for old colum information not to lose info
# Out:
#     index  survived  pclass     sex  ...  deck  embark_town  alive  alone
# 0      79         1       3  female  ...   NaN  Southampton    yes   True
# 1     157         0       3    male  ...   NaN  Southampton     no   True
# 2     178         0       2    male  ...   NaN  Southampton     no   True
# 3     213         0       2    male  ...   NaN  Southampton     no   True
# 4     219         0       2    male  ...   NaN  Southampton     no   True
# 5     244         0       3    male  ...   NaN    Cherbourg     no   True
# 6     253         0       3    male  ...   NaN  Southampton     no  False
# 7     257         1       1  female  ...     B  Southampton    yes   True
# 8     286         1       3    male  ...   NaN  Southampton    yes   True
# 9     308         0       2    male  ...   NaN    Cherbourg     no  False
# 10    309         1       1  female  ...     E    Cherbourg    yes   True
# 11    322         1       2  female  ...   NaN   Queenstown    yes   True
# ...

# %%
filtered_titanic=titanic[titanic["age"]==30].reset_index(drop=True)
filtered_titanic#only reset index you ll see index colum to old info
#but normally u dont need it and to go away it you can use drop true
#for example you want to plot of some variable the old number of index can give you
#riduculas staff
# Out:
#     survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0          1       3  female  30.0  ...   NaN  Southampton    yes   True
# 1          0       3    male  30.0  ...   NaN  Southampton     no   True
# 2          0       2    male  30.0  ...   NaN  Southampton     no   True
# 3          0       2    male  30.0  ...   NaN  Southampton     no   True
# 4          0       2    male  30.0  ...   NaN  Southampton     no   True
# 5          0       3    male  30.0  ...   NaN    Cherbourg     no   True
# 6          0       3    male  30.0  ...   NaN  Southampton     no  False
# 7          1       1  female  30.0  ...     B  Southampton    yes   True
# 8          1       3    male  30.0  ...   NaN  Southampton    yes   True
# 9          0       2    male  30.0  ...   NaN    Cherbourg     no  False
# 10         1       1  female  30.0  ...     E    Cherbourg    yes   True
# 11         1       2  female  30.0  ...   NaN   Queenstown    yes   True
# ...

# %%
#sorting the values
titanic.sort_values(by="fare")
#it ll sort fare lowest to highest

# %%
titanic.sort_values(by="fare",ascending=False)
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 258         1       1  female  35.0  ...   NaN    Cherbourg    yes   True
# 737         1       1    male  35.0  ...     B    Cherbourg    yes   True
# 679         1       1    male  36.0  ...     B    Cherbourg    yes  False
# 88          1       1  female  23.0  ...     C  Southampton    yes  False
# 27          0       1    male  19.0  ...     C  Southampton     no  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 633         0       1    male   NaN  ...   NaN  Southampton     no   True
# 413         0       2    male   NaN  ...   NaN  Southampton     no   True
# 822         0       1    male  38.0  ...   NaN  Southampton     no   True
# 732         0       2    male   NaN  ...   NaN  Southampton     no   True
# 674         0       2    male   NaN  ...   NaN  Southampton     no   True
#
# [891 rows x 15 columns]

# %%
#the aim of this study is showing you depending to ur object there are o lot fonction that some of them  
#you can use for series some of them you can apply for  datafram sometime both.

# %%
titanic.sort_index(ascending=False)

# %%
#changing value infos
titanic["sex"].str.upper()
#here we used string foncution to make all infos in sex must be upp letter
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
#in here when we run dthe titanic orginal didnt change so we can assigng info to table

# %%
titanic["sex"]=titanic["sex"].str.upper()
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE  22.0  ...   NaN  Southampton     no  False
# 1           1       1  FEMALE  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  FEMALE  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  FEMALE  35.0  ...     C  Southampton    yes  False
# 4           0       3    MALE  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    MALE  27.0  ...   NaN  Southampton     no   True
# 887         1       1  FEMALE  19.0  ...     B  Southampton    yes   True
# 888         0       3  FEMALE   NaN  ...   NaN  Southampton     no  False
# 889         1       1    MALE  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    MALE  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
#we can find any info inside to data
titanic[titanic["class"].str.contains("Third")]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE  22.0  ...   NaN  Southampton     no  False
# 2           1       3  FEMALE  26.0  ...   NaN  Southampton    yes   True
# 4           0       3    MALE  35.0  ...   NaN  Southampton     no   True
# 5           0       3    MALE   NaN  ...   NaN   Queenstown     no   True
# 7           0       3    MALE   2.0  ...   NaN  Southampton     no  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 882         0       3  FEMALE  22.0  ...   NaN  Southampton     no   True
# 884         0       3    MALE  25.0  ...   NaN  Southampton     no   True
# 885         0       3  FEMALE  39.0  ...   NaN   Queenstown     no  False
# 888         0       3  FEMALE   NaN  ...   NaN  Southampton     no  False
# 890         0       3    MALE  32.0  ...   NaN   Queenstown     no   True
#
# [491 rows x 15 columns]

# %%
titanic[titanic["age"].str.contains("20")]
#it ll give you eror bec str fonk doesnt work with int values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-e01c23d3496d> in <module>()
# ----> 1 titanic[titanic["age"].str.contains("20")]
#       2 #it ll give you eror bec str fonk doesnt work with int values
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5135             or name in self._accessors
#    5136         ):
# -> 5137             return object.__getattribute__(self, name)
#    5138         else:
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
#to get new dataframe

# %%
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE  22.0  ...   NaN  Southampton     no  False
# 1           1       1  FEMALE  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  FEMALE  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  FEMALE  35.0  ...     C  Southampton    yes  False
# 4           0       3    MALE  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    MALE  27.0  ...   NaN  Southampton     no   True
# 887         1       1  FEMALE  19.0  ...     B  Southampton    yes   True
# 888         0       3  FEMALE   NaN  ...   NaN  Southampton     no  False
# 889         1       1    MALE  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    MALE  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
data_add={"survived":[1,0],"pclass":[1,3],"sex":["female";"male"],"age":[17,20]}
adendum=pd.dataframe(columns=titanic.columns,data=data_add)
adendum
#here will give you same design data like above and we ll connect them
#it ll add at the bottom
# Out:
#   File "<ipython-input-34-eac275151784>", line 1
#     data_add={"survived":[1,0],"pclass":[1,3],"sex":["female";"male"]}
#                                                              ^
# SyntaxError: invalid syntax

# %%
pd.concad([titanic,addendum])

# %%
data_add={"Pclass":[1,2,3],"total cabin amount":[300,400,200]}
extra_info=pc.DataFrame(columns=["pclass","total cabin amount"],data=data_add)
extra_info

# %%
titanic.merge(extra_info,how="left",on="pclass")

# %% [markdown]
# Aggregations

# %%
#describe
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#we can get general staticcal info about data
#also we can get each info about data like mean
titanic.mean()
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
#we can also get spesific colum info
titanic["age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["age"].median()
# Out:
# 28.0

# %%
titanic["age"].mod()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-db8f05d6da35> in <module>()
# ----> 1 titanic["age"].mod()
#
# TypeError: flex_wrapper() missing 1 required positional argument: 'other'

# %%
#how many times uniqu accur
titanic.value_counts()
# Out:
# survived  pclass  sex     age   sibsp  parch  fare      embarked  class  who    adult_male  deck  embark_town  alive  alone
# 1         1       FEMALE  24.0  0      0      69.3000   C         First  woman  False       B     Cherbourg    yes    True     2
#           3       MALE    32.0  0      0      8.0500    S         Third  man    True        E     Southampton  yes    True     1
# 0         3       FEMALE  29.0  1      1      10.4625   S         Third  woman  False       G     Southampton  no     False    1
# 1         1       FEMALE  17.0  1      0      57.0000   S         First  woman  False       B     Southampton  yes    False    1
#                           16.0  0      1      57.9792   C         First  woman  False       B     Cherbourg    yes    False    1
#                                                                                                                               ..
# ...

# %%
titanic["age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
#group by=group thing together
titanic.groupby("sex")

# %%
titanic.groupby("sex")["age"].mean()
# Out:
# sex
# FEMALE    27.915709
# MALE      30.726645
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].count()#how many male how many female
# Out:
# sex
# FEMALE    261
# MALE      453
# Name: age, dtype: int64

# %% [markdown]
# Plotting

# %%
titanic.plot()

# %%
titanic["age"].plot()

# %%
titanic[["age","survived"]].plot()

# %%
titanic[["age","survived"]].plot(x="age",y="survived")

# %%
titanic[["age","survived"]].plot(x="age",y="survived",kind="scatter")

# %%
titanic[["age","survived"]].plot(x="age",y="survived",kind="scatter",figsize=(20,10))

# %%
titanic.hist()
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-881b1ed13105> in <module>()
# ----> 1 titanic.hist()
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     225         legend=legend,
#     226         bins=bins,
# ...

# %%
titanic.hist(figsize=(20,10),bins=100)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-42d4e23df790> in <module>()
# ----> 1 titanic.hist(figsize=(20,10),bins=100)
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     225         legend=legend,
# ...

# %%
from textblob import TextBlob
import pandas as pd

# %% [markdown]
# If you want to increase the readability of your code when applying
# multiple functions to a DataFrame, use pands.DataFrame.pipe
# method.

# %%
def remove_white_space(df: pd.DataFrame):
   df['text'] = df['text'].apply(lambda row:row.strip())
   return df
def get_sentiment(df: pd.DataFrame):
   df['sentiment'] = df['text'].apply(lambda row: TextBlob(row).sentiment[0])
   return df
df = pd.DataFrame({'text': ["It is a beautiful day today "," This movie is terrible"]})
df = (df.pipe(remove_white_space).pipe(get_sentiment))
df
# Out:
#                           text  sentiment
# 0  It is a beautiful day today       0.85
# 1       This movie is terrible      -1.00

# %% [markdown]
# If you want to apply only one function to a column of a DataFrame,
# use apply.

# %%
import pandas as pd
df = pd.DataFrame({"col1": [1, 2],"col2": [3,4]})
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df["col1"] = df["col1"].apply(lambda row: row
* 2)
df
# Out:
#    col1  col2
# 0     2     3
# 1     4     4

# %% [markdown]
# If you want to assign values to multiple new columns, instead of
# assigning them separately, you can do everything in one line of
# code with df.assign.
# In the code below, I first created col3 then use col3 to create
# col4. Everything is in one line of code.

# %%
import pandas as pd
df = pd.DataFrame({"col1": [1, 2],"col2": [3,4]})
df = df.assign(col3=lambda x: x.col1 * 100 + x.col2).assign(col4=lambda x: x.col2 * x.col3)
df
# Out:
#    col1  col2  col3  col4
# 0     1     3   103   309
# 1     2     4   204   816

# %% [markdown]
# If you want to change values of a pandas Series using a dictionary,
# use pd.Series.map.

# %%
s = pd.Series(["a","b","c"])
s.map({"a": 1,"b": 2,"c": 3})
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# When working with pandas DataFrame, if you want to transform
# each element in an iterable to a row, use explode.

# %%
df = pd.DataFrame({"a": [[1, 2], [4, 5]],"b":[11, 13]})
df
# Out:
#         a   b
# 0  [1, 2]  11
# 1  [4, 5]  13

# %%
df.explode("a")
# Out:
#    a   b
# 0  1  11
# 0  2  11
# 1  4  13
# 1  5  13

# %% [markdown]
# Sometimes, you might have a column whose values are strings
# representing different items such as "1, 2".

# %%
df = pd.DataFrame({"a": ["1,2","4,5"],"b":[11, 13]})
df
# Out:
#      a   b
# 0  1,2  11
# 1  4,5  13

# %% [markdown]
# To turn each string into a list, use Series.str.split():

# %%
# Split by comma
df.a = df.a.str.split(",")
df
# Out:
#         a   b
# 0  [1, 2]  11
# 1  [4, 5]  13

# %% [markdown]
# Now you can split elements in the list into multiple rows using
# explode.

# %%
df.explode("a")
# Out:
#    a   b
# 0  1  11
# 0  2  11
# 1  4  13
# 1  5  13

# %% [markdown]
# If you want to use the previous value in a column or a row to fill
# the current missing value in a pandas DataFrame, use
# df.fillna(method=
# ’ffill’). ffill stands for forward fill.

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({"a": [1, np.nan, 3],"b":[4, 5, np.nan],"c": [1, 2, 3]})
df
# Out:
#      a    b  c
# 0  1.0  4.0  1
# 1  NaN  5.0  2
# 2  3.0  NaN  3

# %%
df = df.fillna(method="ffill")
df
# Out:
#      a    b  c
# 0  1.0  4.0  1
# 1  1.0  5.0  2
# 2  3.0  5.0  3
